# %% [markdown]
# # 1. Install Dependencies and Setup

# %%
#!pip install tensorflow tensorflow-gpu opencv-python matplotlib

# %%
#!pip list

# %%
import tensorflow as tf
import os

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %% [markdown]
# # 2. Remove dodgy images

# %%
import cv2
import imghdr

# %%
data_dir = 'data'

# %%
image_exts = ['jpeg','jpg', 'bmp', 'png']

# %%
for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
            # os.remove(image_path)

# %% [markdown]
# # 3. Load Data

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 305 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# # 4. Scale Data

# %%
data = data.map(lambda x,y: (x/255, y))

# %%
data.as_numpy_iterator().next()
# Out:
# (array([[[[0.95686275, 0.83137256, 0.02745098],
#           [0.95686275, 0.83137256, 0.02745098],
#           [0.95686275, 0.83137256, 0.02745098],
#           ...,
#           [0.95686275, 0.83137256, 0.02745098],
#           [0.95686275, 0.83137256, 0.02745098],
#           [0.95686275, 0.83137256, 0.02745098]],
#
#          [[0.95686275, 0.83137256, 0.02745098],
#           [0.95686275, 0.83137256, 0.02745098],
#           [0.95686275, 0.83137256, 0.02745098],
#           ...,
#           [0.95686275, 0.83137256, 0.02745098],
#           [0.95686275, 0.83137256, 0.02745098],
#           [0.95686275, 0.83137256, 0.02745098]],
#
#          [[0.95686275, 0.83137256, 0.02745098],
#           [0.95686275, 0.83137256, 0.02745098],
#           [0.95686275, 0.83137256, 0.02745098],
#           ...,
#           [0.95686275, 0.83137256, 0.02745098],
#           [0.95686275, 0.83137256, 0.02745098],
#           [0.95686275, 0.83137256, 0.02745098]],
#
#          ...,
#
#          [[0.2940564 , 0.2769608 , 0.15594363],
#           [0.15280618, 0.1345167 , 0.07566445],
#           [0.09348575, 0.07558498, 0.0800494 ],
#           ...,
#           [0.06666667, 0.06666667, 0.06666667],
#           [0.06666667, 0.06666667, 0.06666667],
#           [0.06666667, 0.06666667, 0.06666667]],
#
#          [[0.12218137, 0.11170343, 0.07604167],
#           [0.10768995, 0.09807655, 0.08271101],
#           [0.09653129, 0.088534  , 0.11276137],
#           ...,
#           [0.06666667, 0.06666667, 0.06666667],
#           [0.06666667, 0.06666667, 0.06666667],
#           [0.06666667, 0.06666667, 0.06666667]],
#
#          [[0.04313726, 0.03529412, 0.04705882],
#           [0.08529412, 0.08008578, 0.0997549 ],
#           [0.09344362, 0.08952206, 0.134375  ],
#           ...,
#           [0.06666667, 0.06666667, 0.06666667],
#           [0.06666667, 0.06666667, 0.06666667],
#           [0.06666667, 0.06666667, 0.06666667]]],
#
#
#         [[[0.08410477, 0.15489645, 0.19916178],
#           [0.10376839, 0.19590873, 0.2508248 ],
#           [0.12209257, 0.23636954, 0.29328734],
#           ...,
#           [0.13333334, 0.29344052, 0.38238046],
#           [0.11527626, 0.27846202, 0.35693815],
#           [0.10116421, 0.2599375 , 0.34098715]],
#
#          [[0.09845641, 0.1899651 , 0.24707533],
#           [0.12463235, 0.24743819, 0.3171334 ],
#           [0.14514998, 0.28565243, 0.3580789 ],
#           ...,
#           [0.14588264, 0.30268675, 0.38925567],
#           [0.12313113, 0.2916901 , 0.37555146],
#           [0.11654412, 0.2803309 , 0.36429107]],
#
#          [[0.10327819, 0.23645522, 0.30361518],
#           [0.13067722, 0.29983747, 0.37587914],
#           [0.1756283 , 0.3426626 , 0.41750944],
#           ...,
#           [0.15320136, 0.31213236, 0.39552647],
#           [0.13455883, 0.30316496, 0.38280317],
#           [0.12907475, 0.29650736, 0.3788603 ]],
#
#          ...,
#
#          [[0.16027544, 0.19908974, 0.19668496],
#           [0.09700425, 0.14557363, 0.16946135],
#           [0.05208333, 0.0951136 , 0.12339131],
#           ...,
#           [0.17581213, 0.26960832, 0.25304866],
#           [0.1726103 , 0.26278508, 0.25490198],
#           [0.15413603, 0.25490198, 0.25490198]],
#
#          [[0.10413603, 0.16069241, 0.1657193 ],
#           [0.10873425, 0.14559087, 0.18767928],
#           [0.06259191, 0.10031307, 0.12596843],
#           ...,
#           [0.17864583, 0.26840365, 0.26124388],
#           [0.17352942, 0.2627451 , 0.25343138],
#           [0.15718324, 0.25522247, 0.25390506]],
#
#          [[0.04869361, 0.1045257 , 0.11629041],
#           [0.13054535, 0.16170344, 0.21732417],
#           [0.06739885, 0.09994495, 0.12899792],
#           ...,
#           [0.1833915 , 0.27539518, 0.26608768],
#           [0.18103315, 0.27300858, 0.2630656 ],
#           [0.16773346, 0.2636587 , 0.2618511 ]]],
#
#
#         [[[0.99215686, 0.99215686, 0.99215686],
#           [0.98976713, 0.98976713, 0.98976713],
#           [0.99215686, 0.99215686, 0.99215686],
#           ...,
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686]],
#
#          [[0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686],
#           ...,
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686]],
#
#          [[0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686],
#           ...,
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686]],
#
#          ...,
#
#          [[0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686],
#           ...,
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686]],
#
#          [[0.9882353 , 0.9882353 , 0.9882353 ],
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686],
#           ...,
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686]],
#
#          [[0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686],
#           ...,
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99215686, 0.99215686, 0.99215686]]],
#
#
#         ...,
#
#
#         [[[0.8352941 , 0.6392157 , 0.1882353 ],
#           [0.8156863 , 0.6509804 , 0.1882353 ],
#           [0.8156863 , 0.6509804 , 0.1882353 ],
#           ...,
#           [0.23921569, 0.26666668, 0.23529412],
#           [0.24505208, 0.27642465, 0.22503063],
#           [0.23339158, 0.26476413, 0.2139216 ]],
#
#          [[0.8199204 , 0.6293108 , 0.17650747],
#           [0.8156863 , 0.6509804 , 0.1882353 ],
#           [0.80784315, 0.6413143 , 0.18403798],
#           ...,
#           [0.23921569, 0.26848957, 0.23164828],
#           [0.23576212, 0.27241114, 0.21564454],
#           [0.23887102, 0.27416512, 0.20728682]],
#
#          [[0.80784315, 0.6431373 , 0.18039216],
#           [0.8156863 , 0.6509804 , 0.1882353 ],
#           [0.79607844, 0.627451  , 0.1882353 ],
#           ...,
#           [0.2426777 , 0.24140625, 0.18039216],
#           [0.25729933, 0.30373776, 0.22551318],
#           [0.21981464, 0.25503984, 0.18080576]],
#
#          ...,
#
#          [[0.12934282, 0.27444088, 0.06613817],
#           [0.12768076, 0.26885724, 0.09630821],
#           [0.16643688, 0.30761334, 0.13506433],
#           ...,
#           [0.20749846, 0.38789064, 0.2035769 ],
#           [0.17866115, 0.36251533, 0.1764706 ],
#           [0.15699254, 0.32545978, 0.14509805]],
#
#          [[0.25562334, 0.3929103 , 0.23226385],
#           [0.14299938, 0.28417584, 0.11162684],
#           [0.14901961, 0.2901961 , 0.11764706],
#           ...,
#           [0.20749846, 0.38789064, 0.2035769 ],
#           [0.1924326 , 0.37282476, 0.18851103],
#           [0.1685954 , 0.3371539 , 0.15676177]],
#
#          [[0.1037837 , 0.24496017, 0.07241115],
#           [0.12327665, 0.2644531 , 0.0919041 ],
#           [0.13882506, 0.28000152, 0.10745251],
#           ...,
#           [0.18039216, 0.4       , 0.14509805],
#           [0.17977175, 0.3766774 , 0.18431373],
#           [0.19208793, 0.33732384, 0.16470589]]],
#
#
#         [[[0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           ...,
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765]],
#
#          [[0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           ...,
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765]],
#
#          [[0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           ...,
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765]],
#
#          ...,
#
#          [[0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           ...,
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765]],
#
#          [[0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           ...,
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765]],
#
#          [[0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           ...,
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765],
#           [0.03921569, 0.        , 0.09411765]]],
#
#
#         [[[1.        , 1.        , 0.84705883],
#           [0.9124464 , 0.92386645, 0.7556985 ],
#           [0.9657552 , 0.97005975, 0.8350031 ],
#           ...,
#           [0.9794347 , 0.9758961 , 0.8916284 ],
#           [0.9619332 , 0.9657399 , 0.84428614],
#           [1.        , 1.        , 0.88235295]],
#
#          [[0.96013325, 0.96544886, 0.80984986],
#           [0.9473973 , 0.9563931 , 0.798467  ],
#           [0.98779607, 0.9894428 , 0.8700733 ],
#           ...,
#           [0.99032545, 0.9866571 , 0.90277857],
#           [0.9771791 , 0.9784059 , 0.8643804 ],
#           [0.9920266 , 0.9920266 , 0.8637485 ]],
#
#          [[0.9684053 , 0.9726179 , 0.83027726],
#           [0.9806729 , 0.9848855 , 0.8516378 ],
#           [0.93346274, 0.93366843, 0.8227332 ],
#           ...,
#           [0.90908426, 0.90535414, 0.8233875 ],
#           [0.9827729 , 0.9827198 , 0.87238604],
#           [0.9918658 , 0.99005055, 0.862163  ]],
#
#          ...,
#
#          [[0.98366266, 0.98366266, 0.8817019 ],
#           [0.98168504, 0.98168504, 0.8832484 ],
#           [0.8575198 , 0.8575198 , 0.75918955],
#           ...,
#           [0.8558676 , 0.8522087 , 0.7673522 ],
#           [0.9836432 , 0.97943056, 0.88660735],
#           [1.        , 0.9957874 , 0.8953508 ]],
#
#          [[0.9936811 , 0.9936811 , 0.8917203 ],
#           [0.97562164, 0.97562164, 0.87366086],
#           [0.99277264, 0.99277264, 0.89081186],
#           ...,
#           [0.9964342 , 0.98991746, 0.9030685 ],
#           [0.9768331 , 0.9664624 , 0.8681934 ],
#           [0.9974724 , 0.98710173, 0.8812194 ]],
#
#          [[0.98039216, 0.98039216, 0.8784314 ],
#           [0.98039216, 0.98039216, 0.8784314 ],
#           [0.98039216, 0.98039216, 0.8784314 ],
#           ...,
#           [0.99215686, 0.97274053, 0.88589156],
#           [0.99215686, 0.9764706 , 0.8782016 ],
#           [0.99215686, 0.9764706 , 0.87058824]]]], dtype=float32),
#  array([0, 1, 0, 0, 0, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 0, 1, 0, 0, 0, 0, 1,
#         0, 1, 1, 1, 0, 0, 0, 0, 1, 1]))

# %% [markdown]
# # 5. Split Data

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)

# %%
train_size
# Out:
# 7

# %%
val_size
# Out:
# 2

# %%
test_size
# Out:
# 1

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# # 6. Build Deep Learning Model

# %%
train
# Out:
# <TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 7. Train

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=10, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
# 7/7 [==============================] - 14s 1s/step - loss: 1.4849 - accuracy: 0.5045 - val_loss: 0.6776 - val_accuracy: 0.4844
# Epoch 2/10
# 7/7 [==============================] - 11s 1s/step - loss: 0.6767 - accuracy: 0.5938 - val_loss: 0.6661 - val_accuracy: 0.7031
# Epoch 3/10
# 7/7 [==============================] - 12s 1s/step - loss: 0.6522 - accuracy: 0.6696 - val_loss: 0.6269 - val_accuracy: 0.6875
# Epoch 4/10
# 7/7 [==============================] - 9s 1s/step - loss: 0.5923 - accuracy: 0.7366 - val_loss: 0.5035 - val_accuracy: 0.9219
# Epoch 5/10
# 7/7 [==============================] - 14s 2s/step - loss: 0.4792 - accuracy: 0.8036 - val_loss: 0.4049 - val_accuracy: 0.8750
# Epoch 6/10
# 7/7 [==============================] - 10s 953ms/step - loss: 0.4568 - accuracy: 0.8125 - val_loss: 0.4240 - val_accuracy: 0.8438
# Epoch 7/10
# 7/7 [==============================] - 10s 1s/step - loss: 0.3658 - accuracy: 0.8750 - val_loss: 0.2729 - val_accuracy: 0.9062
# Epoch 8/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.2345 - accuracy: 0.9241 - val_loss: 0.2896 - val_accuracy: 0.9062
# Epoch 9/10
# 7/7 [==============================] - 8s 941ms/step - loss: 0.2236 - accuracy: 0.9286 - val_loss: 0.1178 - val_accuracy: 1.0000
# Epoch 10/10
# 7/7 [==============================] - 14s 2s/step - loss: 0.1414 - accuracy: 0.9777 - val_loss: 0.1658 - val_accuracy: 0.9375

# %% [markdown]
# # 8. Plot Performance

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # 9. Evaluate

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 0s 404ms/step

# %%
print(pre.result(), re.result(), acc.result())
# Out:
# tf.Tensor(0.9166667, shape=(), dtype=float32) tf.Tensor(1.0, shape=(), dtype=float32) tf.Tensor(0.9411765, shape=(), dtype=float32)

# %% [markdown]
# # 10. Test

# %%
import cv2

# %%
img = cv2.imread('images1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #Changing BGR to RGB to show images in true colors
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 0s 101ms/step

# %%
yhat
# Out:
# array([[0.17729151]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is Sad')
else:
    print(f'Predicted class is Happy')
# Out:
# Predicted class is Happy

# %% [markdown]
# # 11. Save the Model

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('models','imageclassifier.h5'))

# %%
new_model = load_model('imageclassifier.h5')

# %%
new_model.predict(np.expand_dims(resize/255, 0))
# Out:
# array([[0.01972741]], dtype=float32)

# %%
string='Keerthana'
var1=list(string)
for i in range(len(string)-1,-1,-1):
    print(string[i])
